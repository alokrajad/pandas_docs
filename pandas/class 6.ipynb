# %%
import pandas as pd

# %%
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv')

# %%
x.head()
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
By default the following values are interpreted as NaN: ‘’, ‘#N/A’, ‘#N/A N/A’, ‘#NA’, ‘-1.#IND’, ‘-1.#QNAN’, ‘-NaN’, ‘-nan’, ‘1.#IND’, ‘1.#QNAN’, ‘<NA>’, ‘N/A’, ‘NA’, ‘NULL’, ‘NaN’, ‘n/a’, ‘nan’, ‘null’.

# %%
we can chnge any value to NAN

# %%
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',na_values=0)
x.head()
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            NaN       79520.76
# 4    172534        FL  CLAY COUNTY            NaN      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 NaN
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 NaN
# 2       190724.4       190724.4   190724.40   192476.78                 NaN
# 3            NaN            NaN    79520.76    86854.48                 NaN
# 4            NaN       254281.5   254281.50   246144.49                 NaN
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',na_values=[0,'FL'])
x.head()
# Out:
#    policyID  statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        NaN  CLAY COUNTY       498960.0      498960.00
# 1    448094        NaN  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        NaN  CLAY COUNTY       190724.4      190724.40
# 3    333743        NaN  CLAY COUNTY            NaN       79520.76
# 4    172534        NaN  CLAY COUNTY            NaN      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 NaN
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 NaN
# 2       190724.4       190724.4   190724.40   192476.78                 NaN
# 3            NaN            NaN    79520.76    86854.48                 NaN
# 4            NaN       254281.5   254281.50   246144.49                 NaN
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
#specific column
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',na_values={"eq_site_limit":0})
x.head()
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            NaN       79520.76
# 4    172534        FL  CLAY COUNTY            NaN      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',na_values={"eq_site_limit":0,"fl_site_limit":0})
x.head()
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            NaN       79520.76
# 4    172534        FL  CLAY COUNTY            NaN      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            NaN            0.0    79520.76    86854.48                 0.0
# 4            NaN       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
#if any place it written n/a or any other. then keep_default_na=False will show same 
x=pd.read_csv('data.csv',keep_default_na=False)
x
# Out:
#      Duration  Pulse  Maxpulse Calories
# 0          60    110       130    409.1
# 1          60    117       145    479.0
# 2          60    103       135    340.0
# 3          45    109       175    282.4
# 4          45    117       148    406.0
# 5          60    102       127    300.0
# 6          60    110       136    374.0
# 7          45    104       134    253.3
# 8          30    109       133    195.1
# 9          60     98       124    269.0
# 10         60    103       147    329.3
# 11         60    100       120    250.7
# 12         60    106       128    345.3
# 13         60    104       132    379.3
# 14         60     98       123    275.0
# 15         60     98       120    215.2
# 16         60    100       120    300.0
# 17         45     90       112
# 18         60    103       123    323.0
# 19         45     97       125    243.0
# 20         60    108       131    364.2
# 21         45    100       119    282.0
# 22         60    130       101    300.0
# ...

# %%
#it will show bydefault values in pandas.all n/a or other to NAN
x=pd.read_csv('data.csv',keep_default_na=True)
x
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
#all NaN will chnge to blank
df=pd.read_csv("data.csv",na_filter=False)
df
# Out:
#      Duration  Pulse  Maxpulse Calories
# 0          60    110       130    409.1
# 1          60    117       145    479.0
# 2          60    103       135    340.0
# 3          45    109       175    282.4
# 4          45    117       148    406.0
# 5          60    102       127    300.0
# 6          60    110       136    374.0
# 7          45    104       134    253.3
# 8          30    109       133    195.1
# 9          60     98       124    269.0
# 10         60    103       147    329.3
# 11         60    100       120    250.7
# 12         60    106       128    345.3
# 13         60    104       132    379.3
# 14         60     98       123    275.0
# 15         60     98       120    215.2
# 16         60    100       120    300.0
# 17         45     90       112
# 18         60    103       123    323.0
# 19         45     97       125    243.0
# 20         60    108       131    364.2
# 21         45    100       119    282.0
# 22         60    130       101    300.0
# ...

# %%
import pandas as pd

# %%
x=pd.read_csv('data.csv')

# %%
x.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# 5       False  False     False     False
# 6       False  False     False     False
# 7       False  False     False     False
# 8       False  False     False     False
# 9       False  False     False     False
# 10      False  False     False     False
# 11      False  False     False     False
# 12      False  False     False     False
# 13      False  False     False     False
# 14      False  False     False     False
# 15      False  False     False     False
# 16      False  False     False     False
# 17      False  False     False      True
# 18      False  False     False     False
# 19      False  False     False     False
# 20      False  False     False     False
# 21      False  False     False     False
# ...

# %%
x.isnull().sum()   #null value in each column detail
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
x.isnull().sum().sum()   #total number of null values
# Out:
# 5

# %%
x.notnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        True   True      True      True
# 1        True   True      True      True
# 2        True   True      True      True
# 3        True   True      True      True
# 4        True   True      True      True
# 5        True   True      True      True
# 6        True   True      True      True
# 7        True   True      True      True
# 8        True   True      True      True
# 9        True   True      True      True
# 10       True   True      True      True
# 11       True   True      True      True
# 12       True   True      True      True
# 13       True   True      True      True
# 14       True   True      True      True
# 15       True   True      True      True
# 16       True   True      True      True
# 17       True   True      True     False
# 18       True   True      True      True
# 19       True   True      True      True
# 20       True   True      True      True
# 21       True   True      True      True
# ...

# %%
x.notnull().sum()
# Out:
# Duration    169
# Pulse       169
# Maxpulse    169
# Calories    164
# dtype: int64

# %%
x.notnull().sum().sum()
# Out:
# 671

# %%
 #series
import numpy as np
y=pd.Series([1,2,3,4,np.nan,np.NAN])
y
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    NaN
# dtype: float64

# %%
y.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
y.isnull().sum()
# Out:
# 2

# %%
y.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
y.notnull().sum()
# Out:
# 4
