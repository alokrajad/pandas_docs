# %%
read write csv file 
----------------------

# %%
import pandas as pd

# %%
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv')

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
#nrows--->number of row want to read
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3)
x
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0       498960.0
# 1    448094        FL  CLAY COUNTY      1322376.3      1322376.3
# 2    206893        FL  CLAY COUNTY       190724.4       190724.4
#
#    fl_site_limit  fr_site_limit   tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.0   792148.90                   0
# 1      1322376.3      1322376.3  1322376.3  1438163.57                   0
# 2       190724.4       190724.4   190724.4   192476.78                   0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# 0              9979.2                   0                   0       30.102261
# 1                 0.0                   0                   0       30.063936
# 2                 0.0                   0                   0       30.089579
#
#    point_longitude         line construction  point_granularity
# ...

# %%
#usecols
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,usecols=[0])
x
# Out:
#    policyID
# 0    119736
# 1    448094
# 2    206893

# %%
#usecols
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,usecols=[2,4,5])
x
# Out:
#         county  hu_site_limit  fl_site_limit
# 0  CLAY COUNTY       498960.0       498960.0
# 1  CLAY COUNTY      1322376.3      1322376.3
# 2  CLAY COUNTY       190724.4       190724.4

# %%
#skiprows
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,skiprows=1)
x
# Out:
#    119736  FL  CLAY COUNTY     498960    498960.1   498960.2   498960.3  \
# 0  448094  FL  CLAY COUNTY  1322376.3  1322376.30  1322376.3  1322376.3
# 1  206893  FL  CLAY COUNTY   190724.4   190724.40   190724.4   190724.4
# 2  333743  FL  CLAY COUNTY        0.0    79520.76        0.0        0.0
#
#      498960.4    792148.9  0  9979.2  0.1  0.2  30.102261  -81.711777  \
# 0  1322376.30  1438163.57  0       0    0    0  30.063936  -81.707664
# 1   190724.40   192476.78  0       0    0    0  30.089579  -81.700455
# 2    79520.76    86854.48  0       0    0    0  30.063236  -81.707703
#
#    Residential  Masonry  1
# 0  Residential  Masonry  3
# 1  Residential     Wood  1
# 2  Residential     Wood  3

# %%
#skiprows
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,skiprows=5)
x
# Out:
#    172534  FL  CLAY COUNTY       0     254281.5     0.1  254281.5.1  \
# 0  785275  FL  CLAY COUNTY       0    515035.62       0           0
# 1  995932  FL  CLAY COUNTY       0  19260000.00       0           0
# 2  223488  FL  CLAY COUNTY  328500    328500.00  328500      328500
#
#     254281.5.2    246144.49  0.2    0.3  0.4  0.5  30.060614  -81.702675  \
# 0    515035.62    884419.17    0      0    0    0  30.063236  -81.707703
# 1  19260000.00  20610000.00    0      0    0    0  30.102226  -81.713882
# 2    328500.00    348374.25    0  16425    0    0  30.102217  -81.707146
#
#    Residential                 Wood  1
# 0  Residential              Masonry  3
# 1   Commercial  Reinforced Concrete  1
# 2  Residential                 Wood  1

# %%
#specifi skiprows using index
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,skiprows=[1])
x
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 1    206893        FL  CLAY COUNTY       190724.4      190724.40
# 2    333743        FL  CLAY COUNTY            0.0       79520.76
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0      1322376.3      1322376.3  1322376.30  1438163.57                   0
# 1       190724.4       190724.4   190724.40   192476.78                   0
# 2            0.0            0.0    79520.76    86854.48                   0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# 0                   0                   0                   0       30.063936
# 1                   0                   0                   0       30.089579
# 2                   0                   0                   0       30.063236
#
#    point_longitude         line construction  point_granularity
# ...

# %%
#specifi skiprows using index
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,skiprows=[1,4])
x
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    448094        FL  CLAY COUNTY      1322376.3      1322376.3
# 1    206893        FL  CLAY COUNTY       190724.4       190724.4
# 2    172534        FL  CLAY COUNTY            0.0       254281.5
#
#    fl_site_limit  fr_site_limit   tiv_2011    tiv_2012  eq_site_deductible  \
# 0      1322376.3      1322376.3  1322376.3  1438163.57                   0
# 1       190724.4       190724.4   190724.4   192476.78                   0
# 2            0.0       254281.5   254281.5   246144.49                   0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# 0                   0                   0                   0       30.063936
# 1                   0                   0                   0       30.089579
# 2                   0                   0                   0       30.060614
#
#    point_longitude         line construction  point_granularity
# ...

# %%
# indexcol
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,index_col="policyID")
x
# Out:
#          statecode       county  eq_site_limit  hu_site_limit  fl_site_limit  \
# policyID
# 119736          FL  CLAY COUNTY       498960.0       498960.0       498960.0
# 448094          FL  CLAY COUNTY      1322376.3      1322376.3      1322376.3
# 206893          FL  CLAY COUNTY       190724.4       190724.4       190724.4
#
#           fr_site_limit   tiv_2011    tiv_2012  eq_site_deductible  \
# policyID
# 119736         498960.0   498960.0   792148.90                   0
# 448094        1322376.3  1322376.3  1438163.57                   0
# 206893         190724.4   190724.4   192476.78                   0
#
#           hu_site_deductible  fl_site_deductible  fr_site_deductible  \
# policyID
# 119736                9979.2                   0                   0
# 448094                   0.0                   0                   0
# 206893                   0.0                   0                   0
#
#           point_latitude  point_longitude         line construction  \
# ...

# %%
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,header=1)
x
# Out:
#    119736  FL  CLAY COUNTY     498960    498960.1   498960.2   498960.3  \
# 0  448094  FL  CLAY COUNTY  1322376.3  1322376.30  1322376.3  1322376.3
# 1  206893  FL  CLAY COUNTY   190724.4   190724.40   190724.4   190724.4
# 2  333743  FL  CLAY COUNTY        0.0    79520.76        0.0        0.0
#
#      498960.4    792148.9  0  9979.2  0.1  0.2  30.102261  -81.711777  \
# 0  1322376.30  1438163.57  0       0    0    0  30.063936  -81.707664
# 1   190724.40   192476.78  0       0    0    0  30.089579  -81.700455
# 2    79520.76    86854.48  0       0    0    0  30.063236  -81.707703
#
#    Residential  Masonry  1
# 0  Residential  Masonry  3
# 1  Residential     Wood  1
# 2  Residential     Wood  3

# %%
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,header=None)
x
# Out:
#          0          1            2              3              4   \
# 0  policyID  statecode       county  eq_site_limit  hu_site_limit
# 1    119736         FL  CLAY COUNTY         498960         498960
# 2    448094         FL  CLAY COUNTY      1322376.3      1322376.3
#
#               5              6          7           8                   9   \
# 0  fl_site_limit  fr_site_limit   tiv_2011    tiv_2012  eq_site_deductible
# 1         498960         498960     498960    792148.9                   0
# 2      1322376.3      1322376.3  1322376.3  1438163.57                   0
#
#                    10                  11                  12              13  \
# 0  hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude
# 1              9979.2                   0                   0       30.102261
# 2                   0                   0                   0       30.063936
#
#                 14           15            16                 17
# ...

# %%
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,header=None,prefix='col')
x
# Out:
#        col0       col1         col2           col3           col4  \
# 0  policyID  statecode       county  eq_site_limit  hu_site_limit
# 1    119736         FL  CLAY COUNTY         498960         498960
# 2    448094         FL  CLAY COUNTY      1322376.3      1322376.3
#
#             col5           col6       col7        col8                col9  \
# 0  fl_site_limit  fr_site_limit   tiv_2011    tiv_2012  eq_site_deductible
# 1         498960         498960     498960    792148.9                   0
# 2      1322376.3      1322376.3  1322376.3  1438163.57                   0
#
#                 col10               col11               col12           col13  \
# 0  hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude
# 1              9979.2                   0                   0       30.102261
# 2                   0                   0                   0       30.063936
#
#              col14        col15         col16              col17
# ...

# %%
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,usecols=[2,4,5],names=['a','b','c'])
x
# Out:
#              a              b              c
# 0       county  hu_site_limit  fl_site_limit
# 1  CLAY COUNTY         498960         498960
# 2  CLAY COUNTY      1322376.3      1322376.3

# %%
x=pd.read_csv('data.csv')
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
# Duration    169 non-null int64
# Pulse       169 non-null int64
# Maxpulse    169 non-null int64
# Calories    164 non-null float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
x.dropna()
print(x)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
write
-------

# %%
x=pd.read_csv('data.csv')
