# %%
import pandas as pd

# %%
# interpolate function
# it guess the missing integer value

# %%
df=pd.read_csv("data.csv")

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df[df["Calories"].isnull()]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %%
df.interpolate()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     311.5
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
 dict2=[{"a":7,"b":2},{"a":4,"d":5,"c":5},{"a":4,"d":8,"c":1},{"a":2,"b":8,"c":4},{"a":6,"b":7,"c":2}]
df=pd.DataFrame(dict2)
df
# Out:
#    a    b    c    d
# 0  7  2.0  NaN  NaN
# 1  4  NaN  5.0  5.0
# 2  4  NaN  1.0  8.0
# 3  2  8.0  4.0  NaN
# 4  6  7.0  2.0  NaN

# %%
df.interpolate()
# Out:
#    a    b    c    d
# 0  7  2.0  NaN  NaN
# 1  4  4.0  5.0  5.0
# 2  4  6.0  1.0  8.0
# 3  2  8.0  4.0  8.0
# 4  6  7.0  2.0  8.0

# %%
df.interpolate(method='linear')
# Out:
#    a    b    c    d
# 0  7  2.0  NaN  NaN
# 1  4  4.0  5.0  5.0
# 2  4  6.0  1.0  8.0
# 3  2  8.0  4.0  8.0
# 4  6  7.0  2.0  8.0

# %%
 
df
# Out:
#    a    b    c    d
# 0  7  2.0  NaN  NaN
# 1  4  NaN  5.0  5.0
# 2  4  NaN  1.0  8.0
# 3  2  8.0  4.0  NaN
# 4  6  7.0  2.0  NaN

# %%
 df.interpolate(axis=1)  #data type must be same
# Out:
#      a    b    c    d
# 0  7.0  2.0  2.0  2.0
# 1  4.0  4.5  5.0  5.0
# 2  4.0  2.5  1.0  8.0
# 3  2.0  8.0  4.0  4.0
# 4  6.0  7.0  2.0  2.0

# %%
df
# Out:
#    a    b    c    d
# 0  7  2.0  NaN  NaN
# 1  4  NaN  5.0  5.0
# 2  4  NaN  1.0  8.0
# 3  2  8.0  4.0  NaN
# 4  6  7.0  2.0  NaN

# %%
 df.interpolate(limit=1)
# Out:
#    a    b    c    d
# 0  7  2.0  NaN  NaN
# 1  4  4.0  5.0  5.0
# 2  4  NaN  1.0  8.0
# 3  2  8.0  4.0  8.0
# 4  6  7.0  2.0  NaN

# %%
df
# Out:
#    a    b    c    d
# 0  7  2.0  NaN  NaN
# 1  4  NaN  5.0  5.0
# 2  4  NaN  1.0  8.0
# 3  2  8.0  4.0  NaN
# 4  6  7.0  2.0  NaN

# %%
 df.interpolate(limit=1,limit_direction='backward')
# Out:
#    a    b    c    d
# 0  7  2.0  5.0  5.0
# 1  4  NaN  5.0  5.0
# 2  4  6.0  1.0  8.0
# 3  2  8.0  4.0  NaN
# 4  6  7.0  2.0  NaN

# %%
df
# Out:
#    a    b    c    d
# 0  7  2.0  NaN  NaN
# 1  4  NaN  5.0  5.0
# 2  4  NaN  1.0  8.0
# 3  2  8.0  4.0  NaN
# 4  6  7.0  2.0  NaN

# %%
 df.interpolate(limit_area='inside')
# Out:
#    a    b    c    d
# 0  7  2.0  NaN  NaN
# 1  4  4.0  5.0  5.0
# 2  4  6.0  1.0  8.0
# 3  2  8.0  4.0  NaN
# 4  6  7.0  2.0  NaN

# %%
 df.interpolate(limit_area='outside')
# Out:
#    a    b    c    d
# 0  7  2.0  NaN  NaN
# 1  4  NaN  5.0  5.0
# 2  4  NaN  1.0  8.0
# 3  2  8.0  4.0  8.0
# 4  6  7.0  2.0  8.0
