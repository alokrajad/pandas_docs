# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
#head()-->top 5 rows
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
#head(n)-->

df.head(3)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0

# %%
#tail()-->last 5 row
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.tail(3)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
#dtype
df=pd.read_csv("data.csv",dtype={'Maxpulse':'float64'})
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    117     145.0     479.0
# 2          60    103     135.0     340.0
# 3          45    109     175.0     282.4
# 4          45    117     148.0     406.0
# 5          60    102     127.0     300.0
# 6          60    110     136.0     374.0
# 7          45    104     134.0     253.3
# 8          30    109     133.0     195.1
# 9          60     98     124.0     269.0
# 10         60    103     147.0     329.3
# 11         60    100     120.0     250.7
# 12         60    106     128.0     345.3
# 13         60    104     132.0     379.3
# 14         60     98     123.0     275.0
# 15         60     98     120.0     215.2
# 16         60    100     120.0     300.0
# 17         45     90     112.0       NaN
# 18         60    103     123.0     323.0
# 19         45     97     125.0     243.0
# 20         60    108     131.0     364.2
# 21         45    100     119.0     282.0
# ...

# %%
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,header=None)
x
# Out:
#          0          1            2              3              4   \
# 0  policyID  statecode       county  eq_site_limit  hu_site_limit
# 1    119736         FL  CLAY COUNTY         498960         498960
# 2    448094         FL  CLAY COUNTY      1322376.3      1322376.3
#
#               5              6          7           8                   9   \
# 0  fl_site_limit  fr_site_limit   tiv_2011    tiv_2012  eq_site_deductible
# 1         498960         498960     498960    792148.9                   0
# 2      1322376.3      1322376.3  1322376.3  1438163.57                   0
#
#                    10                  11                  12              13  \
# 0  hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude
# 1              9979.2                   0                   0       30.102261
# 2                   0                   0                   0       30.063936
#
#                 14           15            16                 17
# ...

# %%
#replace any value to True
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,true_values=['FL'])
x
# Out:
#    policyID  statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736       True  CLAY COUNTY       498960.0       498960.0
# 1    448094       True  CLAY COUNTY      1322376.3      1322376.3
# 2    206893       True  CLAY COUNTY       190724.4       190724.4
#
#    fl_site_limit  fr_site_limit   tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.0   792148.90                   0
# 1      1322376.3      1322376.3  1322376.3  1438163.57                   0
# 2       190724.4       190724.4   190724.4   192476.78                   0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# 0              9979.2                   0                   0       30.102261
# 1                 0.0                   0                   0       30.063936
# 2                 0.0                   0                   0       30.089579
#
#    point_longitude         line construction  point_granularity
# ...

# %%
#replace any value to False
x=pd.read_csv('C:\\Users\\acer\\Downloads\\demo_csv.csv',nrows=3,false_values=['CLAY COUNTY'])
x
# Out:
#    policyID statecode  county  eq_site_limit  hu_site_limit  fl_site_limit  \
# 0    119736        FL   False       498960.0       498960.0       498960.0
# 1    448094        FL   False      1322376.3      1322376.3      1322376.3
# 2    206893        FL   False       190724.4       190724.4       190724.4
#
#    fr_site_limit   tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0   498960.0   792148.90                   0
# 1      1322376.3  1322376.3  1438163.57                   0
# 2       190724.4   190724.4   192476.78                   0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# 0              9979.2                   0                   0       30.102261
# 1                 0.0                   0                   0       30.063936
# 2                 0.0                   0                   0       30.089579
#
#    point_longitude         line construction  point_granularity
# ...
