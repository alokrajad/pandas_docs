# %%
#subplot

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import style

# %%
plt.subplot(2,2,1) #row,column,first

plt.subplot(2,2,2) #row,column,second
plt.subplot(2,2,3) #row,column,third
plt.subplot(2,2,4) #row,column,fourth

plt.show()

# %%
plt.subplot(2,2,1) 
plt.pie([1])

plt.subplot(2,2,2) 
plt.pie([1,2])

plt.subplot(2,2,3) 
plt.pie([1,2,3])

plt.subplot(2,2,4) 
plt.pie([1,2,3,4])

plt.show()

# %%
plt.figure(figsize=(18,10))

plt.subplot(3,2,1) 
#line
days=[1,2,3,4,5]
temp=[65.5,38.6,45.6,47.6,76.5]
humid=[23,45,67,56,53]
plt.axis([0,6,0,80])
plt.title("Delhi temprature & humid",fontsize=15)
plt.xlabel("days",fontsize=15)
plt.ylabel("temp Y humid",fontsize=15)
plt.plot(days,temp,'bD-', label='line 1',linewidth=4) 
plt.plot(days,humid,'gD-',linewidth=4)



plt.subplot(3,2,2) 
#histogram
s1_student_age=np.random.randint(18,45,(100))
s2_student_age=np.random.randint(15,40,(100))
bins=[15,20,25,30,35,40,45,50]
plt.hist(s1_student_age,bins,rwidth=0.9)
plt.title("Student Age")
plt.xlabel("student age category")
plt.ylabel("No. student ")






#plt.subplot(3,2,3) 
plt.subplot(323)  #another way
#bargraph
sub=['python','R','AI','ML','DS']
class1=[35,45,36,56,52]
class2=[65,45,65,37,68]
class3=[56,76,45,65,67]
sub_index=np.arange(len(sub))
width=0.2
plt.bar(sub_index,class1,width,
        align='edge',color='g',edgecolor='m',label='class 1',visible=True)
plt.bar(sub_index+width,class2,width,
        align='edge',color='r',edgecolor='m',label='class 1',visible=True)
plt.title("student details",fontsize=28)
plt.xlabel("student details",fontsize=18)
plt.ylabel("student details",fontsize=18)


plt.subplot(3,2,4)
#scatter plot
df=pd.read_csv('C:\\Users\\acer\\Desktop\\python\\pandas\\data.csv')
x=df['Maxpulse']
y=df['Pulse']
plt.scatter(x,y,c='r',marker="*",s=200)
plt.title("pulse Data")
plt.ylabel("pulse")
plt.xlabel("maxpulse")


plt.subplot(3,2,5) 
#piechart
sub=['PY','R','ML','AI',"DS"]
std=[45,15,35,25,30]
x=[0.1,0,0.2,0,0]
colors=['c','b','r','y','g']
plt.pie(std,labels=sub,explode=x,colors=colors,autopct='%0.1f%%')

plt.subplot(3,2,6,projection="polar",facecolor="k") 

plt.show()
